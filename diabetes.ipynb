# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\Excler - DA\\Python'

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is FEDC-E27B
#
#  Directory of D:\Excler - DA\Python
#
# 12/19/2022  09:08 AM             6,011  p 1.ipynb
# 01/09/2023  07:54 PM    <DIR>          .
# 01/09/2023  07:54 PM    <DIR>          ..
# 12/22/2022  03:07 PM    <DIR>          .ipynb_checkpoints
# 12/20/2022  09:42 PM            23,777 diabetes.csv
# 01/09/2023  07:54 PM           255,502 diabetes.ipynb
# 12/20/2022  07:47 PM            15,250 list and dict operation.ipynb
# 12/21/2022  08:09 PM             9,272 Pandas.ipynb
# 12/22/2022  01:28 PM            65,332 pd preprocessing continue.ipynb
# 12/22/2022  09:30 AM            23,122 preprocessing.ipynb
# 01/09/2023  09:12 AM    <DIR>          project
# 01/01/2023  07:51 PM    <DIR>          python
# 12/17/2022  08:02 PM             7,536 Untitled.ipynb
# 12/19/2022  09:06 AM             6,011 Untitled1.ipynb
# 12/19/2022  08:22 PM             6,559 Untitled2.ipynb
# ...

# %%
import pandas as pd

# %%
data.head
# Out:
# <bound method NDFrame.head of       6  148  72  35    0  33.6  0.627  50  1
# 0     1   85  66  29    0  26.6  0.351  31  0
# 1     8  183  64   0    0  23.3  0.672  32  1
# 2     1   89  66  23   94  28.1  0.167  21  0
# 3     0  137  40  35  168  43.1  2.288  33  1
# 4     5  116  74   0    0  25.6  0.201  30  0
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 762  10  101  76  48  180  32.9  0.171  63  0
# 763   2  122  70  27    0  36.8  0.340  27  0
# 764   5  121  72  23  112  26.2  0.245  30  0
# 765   1  126  60   0    0  30.1  0.349  47  1
# 766   1   93  70  31    0  30.4  0.315  23  0
#
# [767 rows x 9 columns]>

# %%
data=pd.read_csv("diabetes.csv")

# %%
label=["Pregnancies","Glucose","BloodPressure","SkinThickness","Insulin","BMI","DiabetesPedigreeFunction","Age","Outcome"]

# %%
data=pd.read_csv("diabetes.csv",names=label)

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data["Outcome"]=data["Outcome"].astype("category")

# %%
data.dtypes
# Out:
# Pregnancies                    int64
# Glucose                        int64
# BloodPressure                  int64
# SkinThickness                  int64
# Insulin                        int64
# BMI                          float64
# DiabetesPedigreeFunction     float64
# Age                            int64
# Outcome                     category
# dtype: object

# %%
col=["Glucose","BloodPressure"]
for i in col:
    data[i]=data[i].astype('float')

# %%
data.dtypes
# Out:
# Pregnancies                    int64
# Glucose                      float64
# BloodPressure                float64
# SkinThickness                  int64
# Insulin                        int64
# BMI                          float64
# DiabetesPedigreeFunction     float64
# Age                            int64
# Outcome                     category
# dtype: object

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  768.000000                768.000000  768.000000
# mean    31.992578                  0.471876   33.240885
# std      7.884160                  0.331329   11.760232
# min      0.000000                  0.078000   21.000000
# ...

# %%
data.shape[0]
# Out:
# 768

# %%
(data[data['Insulin']==0]).shape[0]
# Out:
# 374

# %%
(data[data['BloodPressure']==0]).shape
# Out:
# (35, 9)

# %%
(data[data['BMI']==0]).shape
# Out:
# (11, 9)

# %%
data['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

# %%
fig, axs=plt.subplots()
sns.boxplot(data=data, orient= 'h', palette="Set3")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, axs=plt.subplots()
sns.boxplot(data=data["BMI"], orient= 'h', palette="Set2")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
q75, q25 = np.percentile(data["Insulin"], [75 ,25])
iqr = q75-q25
print("IQR",iqr)
whisker = q75 + (1.5*iqr) # q25 - (1.5*iqr) ## For Lower whisker
print("Upper whisker",whisker)
# Out:
# IQR 127.25
# Upper whisker 318.125

# %%
import numpy as  np

# %%
data["Insulin"]=data["Insulin"].clip(upper=whisker)

# %%
fig, axs = plt.subplots()
sns.boxplot(data=data,orient='h',palette="Set2")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print((data.iloc[:,[1,2,3,4,5]]==0).sum())
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# dtype: int64

# %%
data.iloc[:,[1,2,3,4,5]]=data.iloc[:,[1,2,3,4,5]].replace(0,np.NaN)

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0      NaN  33.6
# 1            1     85.0           66.0           29.0      NaN  26.6
# 2            8    183.0           64.0            NaN      NaN  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age Outcome
# 0                     0.627   50       1
# 1                     0.351   31       0
# 2                     0.672   32       1
# 3                     0.167   21       0
# 4                     2.288   33       1

# %%
data.isnull().sum(axis=0)
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
print("Size before dropping NaN rows",data.shape,"\n")
nan_dropped = data.dropna()
print("\nSize after dropping NaN rows",nan_dropped.shape)
# Out:
# Size before dropping NaN rows (768, 9)
#
#
# Size after dropping NaN rows (392, 9)

# %%
data.isnull().mean()
# Out:
# Pregnancies                 0.000000
# Glucose                     0.006510
# BloodPressure               0.045573
# SkinThickness               0.295573
# Insulin                     0.486979
# BMI                         0.014323
# DiabetesPedigreeFunction    0.000000
# Age                         0.000000
# Outcome                     0.000000
# dtype: float64

# %%
print("size before dropping NaN rows",data.shape,"\n")
# Out:
# size before dropping NaN rows (768, 9)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
import numpy as np

# %%
imputer.fit(data)
# Out:
# SimpleImputer()

# %%
imputed_data=pd.DataFrame(imputer.fit_transform(data),columns=label)

# %%
imputed_data.isnull().mean()
# Out:
# Pregnancies                 0.0
# Glucose                     0.0
# BloodPressure               0.0
# SkinThickness               0.0
# Insulin                     0.0
# BMI                         0.0
# DiabetesPedigreeFunction    0.0
# Age                         0.0
# Outcome                     0.0
# dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
range_scaler = MinMaxScaler()
range_scaled_data = pd.DataFrame(range_scaler.fit_transform(imputed_data),columns=label)

# %%
range_scaled_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      0.226180    0.607510       0.566438       0.207439    0.094326
# std       0.198210    0.160666       0.158654       0.161134    0.136222
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       0.058824    0.497487       0.508197       0.000000    0.000000
# 50%       0.176471    0.587940       0.590164       0.232323    0.036052
# 75%       0.352941    0.704774       0.655738       0.323232    0.150414
# max       1.000000    1.000000       1.000000       1.000000    1.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean     0.476790                  0.168179    0.204015    0.348958
# std      0.117499                  0.141473    0.196004    0.476951
# ...

# %%
from sklearn.preprocessing import StandardScaler
standardizer= StandardScaler()
std_data=pd.DataFrame(standardizer.fit_transform(imputed_data),columns=label)

# %%
std_data.describe()
# Out:
#         Pregnancies       Glucose  BloodPressure  SkinThickness       Insulin  \
# count  7.680000e+02  7.680000e+02   7.680000e+02   7.680000e+02  7.680000e+02
# mean   2.544261e-17  3.614007e-18  -1.327244e-17   7.994184e-17 -3.556183e-17
# std    1.000652e+00  1.000652e+00   1.000652e+00   1.000652e+00  1.000652e+00
# min   -1.141852e+00 -3.783654e+00  -3.572597e+00  -1.288212e+00 -6.928906e-01
# 25%   -8.448851e-01 -6.852363e-01  -3.673367e-01  -1.288212e+00 -6.928906e-01
# 50%   -2.509521e-01 -1.218877e-01   1.496408e-01   1.545332e-01 -4.280622e-01
# 75%    6.399473e-01  6.057709e-01   5.632228e-01   7.190857e-01  4.120079e-01
# max    3.906578e+00  2.444478e+00   2.734528e+00   4.921866e+00  6.652839e+00
#
#                 BMI  DiabetesPedigreeFunction           Age       Outcome
# count  7.680000e+02              7.680000e+02  7.680000e+02  7.680000e+02
# mean   2.295979e-16              2.462585e-16  1.857600e-16  2.408374e-16
# ...

# %%
std_data["Age"]
# Out:
# 0      1.425995
# 1     -0.190672
# 2     -0.105584
# 3     -1.041549
# 4     -0.020496
#          ...
# 763    2.532136
# 764   -0.531023
# 765   -0.275760
# 766    1.170732
# 767   -0.871374
# Name: Age, Length: 768, dtype: float64

# %%
fig, axs=plt.subplots()
sns.histplot(std_data["Age"])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
bins=[0,25,30,35,40,100]
group_names = ['Malnutritioned','Under-weight','Healthy','Over-weight',"obese"]
data["BMI Class"]= pd.cut(data["BMI"],bins,labels=group_names)
data.head(3)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age  Outcome       BMI Class
# 0                     0.627   50        1         Healthy
# 1                     0.351   31        0    Under-weight
# 2                     0.672   32        1  Malnutritioned

# %%
dummified_data=pd.concat([data.iloc[:,:-1],pd.get_dummies(data["BMI Class"])],axis=1)
dummified_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  Malnutritioned  Under-weight  \
# 0                     0.627   50        1               0             0
# 1                     0.351   31        0               0             1
# 2                     0.672   32        1               1             0
# 3                     0.167   21        0               0             1
# 4                     2.288   33        1               0             0
#
#    Healthy  Over-weight  obese
# 0        1            0      0
# 1        0            0      0
# ...

# %%
pd.get_dummies(data["BMI Class"])
# Out:
#      Malnutritioned  Under-weight  Healthy  Over-weight  obese
# 0                 0             0        1            0      0
# 1                 0             1        0            0      0
# 2                 1             0        0            0      0
# 3                 0             1        0            0      0
# 4                 0             0        0            0      1
# ..              ...           ...      ...          ...    ...
# 763               0             0        1            0      0
# 764               0             0        0            1      0
# 765               0             1        0            0      0
# 766               0             0        1            0      0
# 767               0             0        1            0      0
#
# [768 rows x 5 columns]
